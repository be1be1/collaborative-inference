# %%
#from info get graph
from torch.fx import symbolic_trace
from dnn_models.GoogleNet import *
from torchvision.models.feature_extraction import get_graph_node_names
from matplotlib import pyplot as plt
import networkx as nx
import pandas as pd
# import tqam


model = GoogLeNet()
gm = symbolic_trace(model)
# gm.graph.print_tabular()
# print(gm.code)

# train_nodes, eval_nodes = get_graph_node_names(model)
# print(train_nodes,eval_nodes)
a = [{'name': 'conv1_conv', 'operator': 'conv', 'users': 1, 'args': [], 'calculate': 'self.conv1.conv(x)'},
     {'name': 'conv1_relu', 'operator': 'relu', 'users': 1, 'args': ['conv1_conv'],
      'calculate': 'self.conv1.relu(conv1_conv)'},
     {'name': 'maxpool1', 'operator': 'maxpool1', 'users': 1, 'args': ['conv1_relu'],
      'calculate': 'self.maxpool1(conv1_relu)'},
     {'name': 'conv2_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool1'],
      'calculate': 'self.conv2.conv(maxpool1)'},
     {'name': 'conv2_relu', 'operator': 'relu', 'users': 1, 'args': ['conv2_conv'],
      'calculate': 'self.conv2.relu(conv2_conv)'},
     {'name': 'conv3_conv', 'operator': 'conv', 'users': 1, 'args': ['conv2_relu'],
      'calculate': 'self.conv3.conv(conv2_relu)'},
     {'name': 'conv3_relu', 'operator': 'relu', 'users': 1, 'args': ['conv3_conv'],
      'calculate': 'self.conv3.relu(conv3_conv)'},
     {'name': 'maxpool2', 'operator': 'maxpool2', 'users': 4, 'args': ['conv3_relu'],
      'calculate': 'self.maxpool2(conv3_relu)'},
     {'name': 'inception3a_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool2'],
      'calculate': 'self.inception3a.branch1.conv(maxpool2)'},
     {'name': 'inception3a_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch1_conv'],
      'calculate': 'self.inception3a.branch1.relu(inception3a_branch1_conv)'},
     {'name': 'inception3a_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool2'],
      'calculate': 'getattr(self.inception3a.branch2, "0").conv(maxpool2)'},
     {'name': 'inception3a_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch2_0_conv'],
      'calculate': 'getattr(self.inception3a.branch2, "0").relu(inception3a_branch2_0_conv)'},
     {'name': 'inception3a_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3a_branch2_0_relu'],
      'calculate': 'getattr(self.inception3a.branch2, "1").conv(inception3a_branch2_0_relu)'},
     {'name': 'inception3a_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch2_1_conv'],
      'calculate': 'getattr(self.inception3a.branch2, "1").relu(inception3a_branch2_1_conv)'},
     {'name': 'inception3a_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool2'],
      'calculate': 'getattr(self.inception3a.branch3, "0").conv(maxpool2)'},
     {'name': 'inception3a_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch3_0_conv'],
      'calculate': 'getattr(self.inception3a.branch3, "0").relu(inception3a_branch3_0_conv)'},
     {'name': 'inception3a_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3a_branch3_0_relu'],
      'calculate': 'getattr(self.inception3a.branch3, "1").conv(inception3a_branch3_0_relu)'},
     {'name': 'inception3a_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch3_1_conv'],
      'calculate': 'getattr(self.inception3a.branch3, "1").relu(inception3a_branch3_1_conv)'},
     {'name': 'inception3a_branch4_0', 'operator': '0', 'users': 1, 'args': ['maxpool2'],
      'calculate': 'getattr(self.inception3a.branch4, "0")(maxpool2)'},
     {'name': 'inception3a_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3a_branch4_0'],
      'calculate': 'getattr(self.inception3a.branch4, "1").conv(inception3a_branch4_0)'},
     {'name': 'inception3a_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3a_branch4_1_conv'],
      'calculate': 'getattr(self.inception3a.branch4, "1").relu(inception3a_branch4_1_conv)'},
     {'name': 'cat', 'operator': 'cat', 'users': 4,
      'args': ['inception3a_branch1_relu', 'inception3a_branch2_1_relu', 'inception3a_branch3_1_relu',
               'inception3a_branch4_1_relu'],
      'calculate': 'torch.cat([inception3a_branch1_relu, inception3a_branch2_1_relu, inception3a_branch3_1_relu, inception3a_branch4_1_relu], 1)'},
     {'name': 'inception3b_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat'],
      'calculate': 'self.inception3b.branch1.conv(cat)'},
     {'name': 'inception3b_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch1_conv'],
      'calculate': 'self.inception3b.branch1.relu(inception3b_branch1_conv)'},
     {'name': 'inception3b_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat'],
      'calculate': 'getattr(self.inception3b.branch2, "0").conv(cat)'},
     {'name': 'inception3b_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch2_0_conv'],
      'calculate': 'getattr(self.inception3b.branch2, "0").relu(inception3b_branch2_0_conv)'},
     {'name': 'inception3b_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3b_branch2_0_relu'],
      'calculate': 'getattr(self.inception3b.branch2, "1").conv(inception3b_branch2_0_relu)'},
     {'name': 'inception3b_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch2_1_conv'],
      'calculate': 'getattr(self.inception3b.branch2, "1").relu(inception3b_branch2_1_conv)'},
     {'name': 'inception3b_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat'],
      'calculate': 'getattr(self.inception3b.branch3, "0").conv(cat)'},
     {'name': 'inception3b_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch3_0_conv'],
      'calculate': 'getattr(self.inception3b.branch3, "0").relu(inception3b_branch3_0_conv)'},
     {'name': 'inception3b_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3b_branch3_0_relu'],
      'calculate': 'getattr(self.inception3b.branch3, "1").conv(inception3b_branch3_0_relu)'},
     {'name': 'inception3b_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch3_1_conv'],
      'calculate': 'getattr(self.inception3b.branch3, "1").relu(inception3b_branch3_1_conv)'},
     {'name': 'inception3b_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat'],
      'calculate': 'getattr(self.inception3b.branch4, "0")(cat)'},
     {'name': 'inception3b_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception3b_branch4_0'],
      'calculate': 'getattr(self.inception3b.branch4, "1").conv(inception3b_branch4_0)'},
     {'name': 'inception3b_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception3b_branch4_1_conv'],
      'calculate': 'getattr(self.inception3b.branch4, "1").relu(inception3b_branch4_1_conv)'},
     {'name': 'cat_1', 'operator': '1', 'users': 1,
      'args': ['inception3b_branch1_relu', 'inception3b_branch2_1_relu', 'inception3b_branch3_1_relu',
               'inception3b_branch4_1_relu'],
      'calculate': 'torch.cat([inception3b_branch1_relu, inception3b_branch2_1_relu, inception3b_branch3_1_relu, inception3b_branch4_1_relu], 1)'},
     {'name': 'maxpool3', 'operator': 'maxpool3', 'users': 4, 'args': ['cat_1'], 'calculate': 'self.maxpool3(cat_1)'},
     {'name': 'inception4a_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool3'],
      'calculate': 'self.inception4a.branch1.conv(maxpool3)'},
     {'name': 'inception4a_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch1_conv'],
      'calculate': 'self.inception4a.branch1.relu(inception4a_branch1_conv)'},
     {'name': 'inception4a_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool3'],
      'calculate': 'getattr(self.inception4a.branch2, "0").conv(maxpool3)'},
     {'name': 'inception4a_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch2_0_conv'],
      'calculate': 'getattr(self.inception4a.branch2, "0").relu(inception4a_branch2_0_conv)'},
     {'name': 'inception4a_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4a_branch2_0_relu'],
      'calculate': 'getattr(self.inception4a.branch2, "1").conv(inception4a_branch2_0_relu)'},
     {'name': 'inception4a_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch2_1_conv'],
      'calculate': 'getattr(self.inception4a.branch2, "1").relu(inception4a_branch2_1_conv)'},
     {'name': 'inception4a_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool3'],
      'calculate': 'getattr(self.inception4a.branch3, "0").conv(maxpool3)'},
     {'name': 'inception4a_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch3_0_conv'],
      'calculate': 'getattr(self.inception4a.branch3, "0").relu(inception4a_branch3_0_conv)'},
     {'name': 'inception4a_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4a_branch3_0_relu'],
      'calculate': 'getattr(self.inception4a.branch3, "1").conv(inception4a_branch3_0_relu)'},
     {'name': 'inception4a_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch3_1_conv'],
      'calculate': 'getattr(self.inception4a.branch3, "1").relu(inception4a_branch3_1_conv)'},
     {'name': 'inception4a_branch4_0', 'operator': '0', 'users': 1, 'args': ['maxpool3'],
      'calculate': 'getattr(self.inception4a.branch4, "0")(maxpool3)'},
     {'name': 'inception4a_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4a_branch4_0'],
      'calculate': 'getattr(self.inception4a.branch4, "1").conv(inception4a_branch4_0)'},
     {'name': 'inception4a_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4a_branch4_1_conv'],
      'calculate': 'getattr(self.inception4a.branch4, "1").relu(inception4a_branch4_1_conv)'},
     {'name': 'cat_2', 'operator': '2', 'users': 4,
      'args': ['inception4a_branch1_relu', 'inception4a_branch2_1_relu', 'inception4a_branch3_1_relu',
               'inception4a_branch4_1_relu'],
      'calculate': 'torch.cat([inception4a_branch1_relu, inception4a_branch2_1_relu, inception4a_branch3_1_relu, inception4a_branch4_1_relu], 1)'},
     {'name': 'inception4b_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_2'],
      'calculate': 'self.inception4b.branch1.conv(cat_2)'},
     {'name': 'inception4b_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch1_conv'],
      'calculate': 'self.inception4b.branch1.relu(inception4b_branch1_conv)'},
     {'name': 'inception4b_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_2'],
      'calculate': 'getattr(self.inception4b.branch2, "0").conv(cat_2)'},
     {'name': 'inception4b_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch2_0_conv'],
      'calculate': 'getattr(self.inception4b.branch2, "0").relu(inception4b_branch2_0_conv)'},
     {'name': 'inception4b_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4b_branch2_0_relu'],
      'calculate': 'getattr(self.inception4b.branch2, "1").conv(inception4b_branch2_0_relu)'},
     {'name': 'inception4b_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch2_1_conv'],
      'calculate': 'getattr(self.inception4b.branch2, "1").relu(inception4b_branch2_1_conv)'},
     {'name': 'inception4b_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_2'],
      'calculate': 'getattr(self.inception4b.branch3, "0").conv(cat_2)'},
     {'name': 'inception4b_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch3_0_conv'],
      'calculate': 'getattr(self.inception4b.branch3, "0").relu(inception4b_branch3_0_conv)'},
     {'name': 'inception4b_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4b_branch3_0_relu'],
      'calculate': 'getattr(self.inception4b.branch3, "1").conv(inception4b_branch3_0_relu)'},
     {'name': 'inception4b_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch3_1_conv'],
      'calculate': 'getattr(self.inception4b.branch3, "1").relu(inception4b_branch3_1_conv)'},
     {'name': 'inception4b_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat_2'],
      'calculate': 'getattr(self.inception4b.branch4, "0")(cat_2)'},
     {'name': 'inception4b_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4b_branch4_0'],
      'calculate': 'getattr(self.inception4b.branch4, "1").conv(inception4b_branch4_0)'},
     {'name': 'inception4b_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4b_branch4_1_conv'],
      'calculate': 'getattr(self.inception4b.branch4, "1").relu(inception4b_branch4_1_conv)'},
     {'name': 'cat_3', 'operator': '3', 'users': 4,
      'args': ['inception4b_branch1_relu', 'inception4b_branch2_1_relu', 'inception4b_branch3_1_relu',
               'inception4b_branch4_1_relu'],
      'calculate': 'torch.cat([inception4b_branch1_relu, inception4b_branch2_1_relu, inception4b_branch3_1_relu, inception4b_branch4_1_relu], 1)'},
     {'name': 'inception4c_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_3'],
      'calculate': 'self.inception4c.branch1.conv(cat_3)'},
     {'name': 'inception4c_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch1_conv'],
      'calculate': 'self.inception4c.branch1.relu(inception4c_branch1_conv)'},
     {'name': 'inception4c_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_3'],
      'calculate': 'getattr(self.inception4c.branch2, "0").conv(cat_3)'},
     {'name': 'inception4c_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch2_0_conv'],
      'calculate': 'getattr(self.inception4c.branch2, "0").relu(inception4c_branch2_0_conv)'},
     {'name': 'inception4c_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4c_branch2_0_relu'],
      'calculate': 'getattr(self.inception4c.branch2, "1").conv(inception4c_branch2_0_relu)'},
     {'name': 'inception4c_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch2_1_conv'],
      'calculate': 'getattr(self.inception4c.branch2, "1").relu(inception4c_branch2_1_conv)'},
     {'name': 'inception4c_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_3'],
      'calculate': 'getattr(self.inception4c.branch3, "0").conv(cat_3)'},
     {'name': 'inception4c_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch3_0_conv'],
      'calculate': 'getattr(self.inception4c.branch3, "0").relu(inception4c_branch3_0_conv)'},
     {'name': 'inception4c_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4c_branch3_0_relu'],
      'calculate': 'getattr(self.inception4c.branch3, "1").conv(inception4c_branch3_0_relu)'},
     {'name': 'inception4c_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch3_1_conv'],
      'calculate': 'getattr(self.inception4c.branch3, "1").relu(inception4c_branch3_1_conv)'},
     {'name': 'inception4c_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat_3'],
      'calculate': 'getattr(self.inception4c.branch4, "0")(cat_3)'},
     {'name': 'inception4c_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4c_branch4_0'],
      'calculate': 'getattr(self.inception4c.branch4, "1").conv(inception4c_branch4_0)'},
     {'name': 'inception4c_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4c_branch4_1_conv'],
      'calculate': 'getattr(self.inception4c.branch4, "1").relu(inception4c_branch4_1_conv)'},
     {'name': 'cat_4', 'operator': '4', 'users': 4,
      'args': ['inception4c_branch1_relu', 'inception4c_branch2_1_relu', 'inception4c_branch3_1_relu',
               'inception4c_branch4_1_relu'],
      'calculate': 'torch.cat([inception4c_branch1_relu, inception4c_branch2_1_relu, inception4c_branch3_1_relu, inception4c_branch4_1_relu], 1)'},
     {'name': 'inception4d_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_4'],
      'calculate': 'self.inception4d.branch1.conv(cat_4)'},
     {'name': 'inception4d_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch1_conv'],
      'calculate': 'self.inception4d.branch1.relu(inception4d_branch1_conv)'},
     {'name': 'inception4d_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_4'],
      'calculate': 'getattr(self.inception4d.branch2, "0").conv(cat_4)'},
     {'name': 'inception4d_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch2_0_conv'],
      'calculate': 'getattr(self.inception4d.branch2, "0").relu(inception4d_branch2_0_conv)'},
     {'name': 'inception4d_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4d_branch2_0_relu'],
      'calculate': 'getattr(self.inception4d.branch2, "1").conv(inception4d_branch2_0_relu)'},
     {'name': 'inception4d_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch2_1_conv'],
      'calculate': 'getattr(self.inception4d.branch2, "1").relu(inception4d_branch2_1_conv)'},
     {'name': 'inception4d_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_4'],
      'calculate': 'getattr(self.inception4d.branch3, "0").conv(cat_4)'},
     {'name': 'inception4d_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch3_0_conv'],
      'calculate': 'getattr(self.inception4d.branch3, "0").relu(inception4d_branch3_0_conv)'},
     {'name': 'inception4d_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4d_branch3_0_relu'],
      'calculate': 'getattr(self.inception4d.branch3, "1").conv(inception4d_branch3_0_relu)'},
     {'name': 'inception4d_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch3_1_conv'],
      'calculate': 'getattr(self.inception4d.branch3, "1").relu(inception4d_branch3_1_conv)'},
     {'name': 'inception4d_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat_4'],
      'calculate': 'getattr(self.inception4d.branch4, "0")(cat_4)'},
     {'name': 'inception4d_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4d_branch4_0'],
      'calculate': 'getattr(self.inception4d.branch4, "1").conv(inception4d_branch4_0)'},
     {'name': 'inception4d_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4d_branch4_1_conv'],
      'calculate': 'getattr(self.inception4d.branch4, "1").relu(inception4d_branch4_1_conv)'},
     {'name': 'cat_5', 'operator': '5', 'users': 4,
      'args': ['inception4d_branch1_relu', 'inception4d_branch2_1_relu', 'inception4d_branch3_1_relu',
               'inception4d_branch4_1_relu'],
      'calculate': 'torch.cat([inception4d_branch1_relu, inception4d_branch2_1_relu, inception4d_branch3_1_relu, inception4d_branch4_1_relu], 1)'},
     {'name': 'inception4e_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_5'],
      'calculate': 'self.inception4e.branch1.conv(cat_5)'},
     {'name': 'inception4e_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch1_conv'],
      'calculate': 'self.inception4e.branch1.relu(inception4e_branch1_conv)'},
     {'name': 'inception4e_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_5'],
      'calculate': 'getattr(self.inception4e.branch2, "0").conv(cat_5)'},
     {'name': 'inception4e_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch2_0_conv'],
      'calculate': 'getattr(self.inception4e.branch2, "0").relu(inception4e_branch2_0_conv)'},
     {'name': 'inception4e_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4e_branch2_0_relu'],
      'calculate': 'getattr(self.inception4e.branch2, "1").conv(inception4e_branch2_0_relu)'},
     {'name': 'inception4e_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch2_1_conv'],
      'calculate': 'getattr(self.inception4e.branch2, "1").relu(inception4e_branch2_1_conv)'},
     {'name': 'inception4e_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_5'],
      'calculate': 'getattr(self.inception4e.branch3, "0").conv(cat_5)'},
     {'name': 'inception4e_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch3_0_conv'],
      'calculate': 'getattr(self.inception4e.branch3, "0").relu(inception4e_branch3_0_conv)'},
     {'name': 'inception4e_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4e_branch3_0_relu'],
      'calculate': 'getattr(self.inception4e.branch3, "1").conv(inception4e_branch3_0_relu)'},
     {'name': 'inception4e_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch3_1_conv'],
      'calculate': 'getattr(self.inception4e.branch3, "1").relu(inception4e_branch3_1_conv)'},
     {'name': 'inception4e_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat_5'],
      'calculate': 'getattr(self.inception4e.branch4, "0")(cat_5)'},
     {'name': 'inception4e_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception4e_branch4_0'],
      'calculate': 'getattr(self.inception4e.branch4, "1").conv(inception4e_branch4_0)'},
     {'name': 'inception4e_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception4e_branch4_1_conv'],
      'calculate': 'getattr(self.inception4e.branch4, "1").relu(inception4e_branch4_1_conv)'},
     {'name': 'cat_6', 'operator': '6', 'users': 1,
      'args': ['inception4e_branch1_relu', 'inception4e_branch2_1_relu', 'inception4e_branch3_1_relu',
               'inception4e_branch4_1_relu'],
      'calculate': 'torch.cat([inception4e_branch1_relu, inception4e_branch2_1_relu, inception4e_branch3_1_relu, inception4e_branch4_1_relu], 1)'},
     {'name': 'maxpool4', 'operator': 'maxpool4', 'users': 4, 'args': ['cat_6'], 'calculate': 'self.maxpool4(cat_6)'},
     {'name': 'inception5a_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool4'],
      'calculate': 'self.inception5a.branch1.conv(maxpool4)'},
     {'name': 'inception5a_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch1_conv'],
      'calculate': 'self.inception5a.branch1.relu(inception5a_branch1_conv)'},
     {'name': 'inception5a_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool4'],
      'calculate': 'getattr(self.inception5a.branch2, "0").conv(maxpool4)'},
     {'name': 'inception5a_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch2_0_conv'],
      'calculate': 'getattr(self.inception5a.branch2, "0").relu(inception5a_branch2_0_conv)'},
     {'name': 'inception5a_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5a_branch2_0_relu'],
      'calculate': 'getattr(self.inception5a.branch2, "1").conv(inception5a_branch2_0_relu)'},
     {'name': 'inception5a_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch2_1_conv'],
      'calculate': 'getattr(self.inception5a.branch2, "1").relu(inception5a_branch2_1_conv)'},
     {'name': 'inception5a_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['maxpool4'],
      'calculate': 'getattr(self.inception5a.branch3, "0").conv(maxpool4)'},
     {'name': 'inception5a_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch3_0_conv'],
      'calculate': 'getattr(self.inception5a.branch3, "0").relu(inception5a_branch3_0_conv)'},
     {'name': 'inception5a_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5a_branch3_0_relu'],
      'calculate': 'getattr(self.inception5a.branch3, "1").conv(inception5a_branch3_0_relu)'},
     {'name': 'inception5a_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch3_1_conv'],
      'calculate': 'getattr(self.inception5a.branch3, "1").relu(inception5a_branch3_1_conv)'},
     {'name': 'inception5a_branch4_0', 'operator': '0', 'users': 1, 'args': ['maxpool4'],
      'calculate': 'getattr(self.inception5a.branch4, "0")(maxpool4)'},
     {'name': 'inception5a_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5a_branch4_0'],
      'calculate': 'getattr(self.inception5a.branch4, "1").conv(inception5a_branch4_0)'},
     {'name': 'inception5a_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5a_branch4_1_conv'],
      'calculate': 'getattr(self.inception5a.branch4, "1").relu(inception5a_branch4_1_conv)'},
     {'name': 'cat_7', 'operator': '7', 'users': 4,
      'args': ['inception5a_branch1_relu', 'inception5a_branch2_1_relu', 'inception5a_branch3_1_relu',
               'inception5a_branch4_1_relu'],
      'calculate': 'torch.cat([inception5a_branch1_relu, inception5a_branch2_1_relu, inception5a_branch3_1_relu, inception5a_branch4_1_relu], 1)'},
     {'name': 'inception5b_branch1_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_7'],
      'calculate': 'self.inception5b.branch1.conv(cat_7)'},
     {'name': 'inception5b_branch1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch1_conv'],
      'calculate': 'self.inception5b.branch1.relu(inception5b_branch1_conv)'},
     {'name': 'inception5b_branch2_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_7'],
      'calculate': 'getattr(self.inception5b.branch2, "0").conv(cat_7)'},
     {'name': 'inception5b_branch2_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch2_0_conv'],
      'calculate': 'getattr(self.inception5b.branch2, "0").relu(inception5b_branch2_0_conv)'},
     {'name': 'inception5b_branch2_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5b_branch2_0_relu'],
      'calculate': 'getattr(self.inception5b.branch2, "1").conv(inception5b_branch2_0_relu)'},
     {'name': 'inception5b_branch2_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch2_1_conv'],
      'calculate': 'getattr(self.inception5b.branch2, "1").relu(inception5b_branch2_1_conv)'},
     {'name': 'inception5b_branch3_0_conv', 'operator': 'conv', 'users': 1, 'args': ['cat_7'],
      'calculate': 'getattr(self.inception5b.branch3, "0").conv(cat_7)'},
     {'name': 'inception5b_branch3_0_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch3_0_conv'],
      'calculate': 'getattr(self.inception5b.branch3, "0").relu(inception5b_branch3_0_conv)'},
     {'name': 'inception5b_branch3_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5b_branch3_0_relu'],
      'calculate': 'getattr(self.inception5b.branch3, "1").conv(inception5b_branch3_0_relu)'},
     {'name': 'inception5b_branch3_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch3_1_conv'],
      'calculate': 'getattr(self.inception5b.branch3, "1").relu(inception5b_branch3_1_conv)'},
     {'name': 'inception5b_branch4_0', 'operator': '0', 'users': 1, 'args': ['cat_7'],
      'calculate': 'getattr(self.inception5b.branch4, "0")(cat_7)'},
     {'name': 'inception5b_branch4_1_conv', 'operator': 'conv', 'users': 1, 'args': ['inception5b_branch4_0'],
      'calculate': 'getattr(self.inception5b.branch4, "1").conv(inception5b_branch4_0)'},
     {'name': 'inception5b_branch4_1_relu', 'operator': 'relu', 'users': 1, 'args': ['inception5b_branch4_1_conv'],
      'calculate': 'getattr(self.inception5b.branch4, "1").relu(inception5b_branch4_1_conv)'},
     {'name': 'cat_8', 'operator': '8', 'users': 1,
      'args': ['inception5b_branch1_relu', 'inception5b_branch2_1_relu', 'inception5b_branch3_1_relu',
               'inception5b_branch4_1_relu'],
      'calculate': 'torch.cat([inception5b_branch1_relu, inception5b_branch2_1_relu, inception5b_branch3_1_relu, inception5b_branch4_1_relu], 1)'},
     {'name': 'avgpool', 'operator': 'avgpool', 'users': 1, 'args': ['cat_8'], 'calculate': 'self.avgpool(cat_8)'},
     {'name': 'flatten', 'operator': 'flatten', 'users': 1, 'args': ['avgpool'],
      'calculate': 'torch.flatten(avgpool, 1)'},
     {'name': 'dropout', 'operator': 'dropout', 'users': 1, 'args': ['flatten'], 'calculate': 'self.dropout(flatten)'},
     {'name': 'fc', 'operator': 'fc', 'users': 1, 'args': ['dropout'], 'calculate': 'self.fc(dropout)'}]
# df = pd.DataFrame(a)
key1 = []
key2 = []
key3 = []
key4 = []
key5 = []
for k in a:
    if len(k['args']) == 1:

        key1.append(str(k['args'][0]))
        key2.append(k['name'])
        key3.append(k['operator'])
        key4.append(k['calculate'])
        key5.append(k['args'])


    elif len(k['args']) == 0:
        key1.append(k['name'])
        key2.append(k['name'])
        key3.append(k['operator'])
        key4.append(k['calculate'])
        key5.append(k['args'])
c = {'key1': key1, 'key2': key2, 'key3': key3, 'key4': key4, 'key5': key5}
G = nx.from_pandas_edgelist(c, 'key1', 'key2', create_using=nx.DiGraph())
for k in a:
    if len(k['args']) > 1:
        G.add_node(k['name'])
        G.nodes[k['name']]['operator'] = k['operator']
        G.nodes[k['name']]['calculate'] = k['calculate']
        G.nodes[k['name']]['args'] = k['args']

        for i in k['args']:
            G.add_edge(str(k['name']), str(i))
for i in key2:
    G.nodes[i]['operator'] = c['key3'][c['key2'].index(i)]
    G.nodes[i]['calculate'] = c['key4'][c['key2'].index(i)]
    G.nodes[i]['args'] = c['key5'][c['key2'].index(i)]

# print(c['key3'].index('relu'))
fig, ax = plt.subplots(figsize=(30, 30))
pos = nx.networkx.spiral_layout(G, resolution=0.7)
# pos = nx.networkx.shell_layou(G)
# pos = nx.networkx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=100, alpha=1, linewidths=70, ax=ax, horizontalalignment='left')

# nx.draw_networkx_labels(G,pos,G.nodes,font_size=15,font_family='sans-serif', horizontalalignment='right')
G.remove_edge('conv1_conv', 'conv1_conv')
plt.savefig("1.jpg", dpi=1000) #画图

# %%
from torch import nn
from torch.nn import functional as F
import torch


class GoogLeNet(nn.Module):
    def __init__(self, num_classes=1000, aux_logits=True, init_weights=False):
        super(GoogLeNet, self).__init__()
        self.aux_logits = aux_logits

        self.conv1 = BasicConv2d(1, 64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=3, padding=1)
        self.maxpool2 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)

    def forward(self, x):
        # N x 3 x 224 x 224
        x = self.conv1(x)
        # N x 64 x 112 x 112
        x = self.maxpool1(x)
        # N x 64 x 56 x 56
        x = self.conv2(x)
        # N x 64 x 56 x 56
        x = self.conv3(x)
        # N x 192 x 56 x 56
        x = self.maxpool2(x)

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

#inception结构
class Inception(nn.Module):
    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()

        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)   # 保证输出大小等于输入大小
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)   # 保证输出大小等于输入大小
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        outputs = [branch1, branch2, branch3, branch4]
        return torch.cat(outputs, 1)


#辅助分类器
class InceptionAux(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(InceptionAux, self).__init__()
        self.averagePool = nn.AvgPool2d(kernel_size=5, stride=3)
        self.conv = BasicConv2d(in_channels, 128, kernel_size=1)  # output[batch, 128, 4, 4]

        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

    def forward(self, x):
        # aux1: N x 512 x 14 x 14, aux2: N x 528 x 14 x 14
        x = self.averagePool(x)
        # aux1: N x 512 x 4 x 4, aux2: N x 528 x 4 x 4
        x = self.conv(x)
        # N x 128 x 4 x 4
        x = torch.flatten(x, 1)
        x = F.dropout(x, 0.5, training=self.training)
        # N x 2048
        x = F.relu(self.fc1(x), inplace=True)
        x = F.dropout(x, 0.5, training=self.training)
        # N x 1024
        x = self.fc2(x)
        # N x num_classes
        return x


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        return x

# %%
import re
from torch.autograd import Variable

net = GoogLeNet()
branch = []

a = ({"x": "torch.rand(size=(1, 1, 96, 96))"})

def infer(name, cal, value):
    
    if not name:  # first one
        func = cal.split('self.', 1)[1]
        t = a.get('x')
        res = func.replace('x', t)
        res = 'net.' + res
        r = eval(res)

    elif not ('getattr' in cal):
        func = cal.split('self.', 1)[1]
        for i in name:
            x = a.get(i)
           
            t = torch.load(x)
            res = func.replace(i, '')
            res = res.split('(', 1)[0]
            res = 'net.' + res
            r = eval(res).eval()(t)

    else:

        res,t = branchinfer(cal, value, name)
        res = 'net.' + res
        r = eval(res).eval()(t)

    r = r.detach()
    add = "{}.pt".format(value)
  
    torch.save(r, add)

    a.update({value: add})


def branchinfer(func, value, name):
    
    if any(x in value for x in ["relu", "conv"]):
        func = func.rsplit('.', 1)[1]
        
        for i in name:
            x = a.get(i)
            t = torch.load(x)
            res = func.replace(i, '')
            res = res.split('(', 1)[0]

        res = '.' + res
    else:
        
        func = func.split(')', 1)[1]
        for i in name:
            x = a.get(i)
            t = torch.load(x)
            res = func.replace(i, '')
            res = res.split('(', 1)[0]
            
    s = str()
    for i in value.split('_'):
        if i in ["relu", "conv"]:
            pass
        elif not i.isdigit():
            s += i + '.'
        else:
            s = s.strip('.')
            s += '[' + i + ']'
    res = s + res

    return res, t


def catinfer(name, cal, value):
    
    if len(name) == 1:
        x = a.get(str(name[0]))
        t = torch.load(x)
        res = cal.replace(name[0], '')
        res = res.split('(', 1)[0]
        r = eval(res)(t,1)
    else:
        branch1 = torch.load(a.get(str(name[0])))
        branch2 = torch.load(a.get(str(name[1])))
        branch3 = torch.load(a.get(str(name[2])))
        branch4 = torch.load(a.get(str(name[3])))

        outputs = [branch1, branch2, branch3, branch4]
        r = torch.cat(outputs, 1)
    add = "{}.pt".format(value)
    torch.save(r, add)
   
    a.update({value: add})


for key, value in enumerate(G.nodes):
    calculate = G.nodes[value]['calculate']
    args = G.nodes[value]['args']
    if 'torch' in calculate:
        catinfer(args, calculate, value)
    else:

        if G.degree[value] > 2:
            branch.append(value)
        infer(args, calculate, value) 

print(torch.load(a.get(list(a.keys())[-1])))
